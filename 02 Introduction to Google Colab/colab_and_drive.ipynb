# %% [markdown]
# Mount google drive so we can access all the saved/uploaded contents in this session.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# If you follow the intro_to_colab notebook correctly, you should see predicted_data.csv in the Files tab in **/content/drive/MyDrive/IT7143 Module 2**
#
# We can directly read data from there

# %%
import pandas as pd

predicted_data = pd.read_csv('drive/MyDrive/IT7143 Module 2/predicted_data.csv')
predicted_data
# Out:
#   student_id first_name last_name major  study_time  GPA_predict
# 0    zcd1345  Gabrielle     Davis    IT         6.0     3.341953
# 1    xcv6241      Helen    Wilson    CS         5.6     3.275744
# 2    vow6064        Ian     Moore   SWE         7.4     3.573684
# 3    zxc1063       Jack    Thomas    IT         3.4     2.911594
# 4    pca0414      Kayla    Harris    CS         4.1     3.027460

# %% [markdown]
# As you can see, this eliminates the needs to upload/download files after every session. You just have to upload data once, then continue your projects in multiple sessions.
